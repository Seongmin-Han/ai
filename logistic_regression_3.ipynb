# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score

file = '/content/drive/MyDrive/Colab Notebooks/winequality-red.csv'
data = pd.read_csv(file)

data['quality'] = data['quality'].apply(lambda x: 1 if x >= 6 else 0)

X = data.drop('quality', axis=1)
y = data['quality']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=100)

base_model = LogisticRegression(max_iter=1000, random_state=100)
base_model.fit(X_train, y_train)

base_pred = base_model.predict(X_test)
base_accuracy = accuracy_score(y_test, base_pred)

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

X_train_scaled, X_test_scaled, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=100)

fe_model = LogisticRegression(max_iter=1000, random_state=100)
fe_model.fit(X_train_scaled, y_train)

fe_pred = fe_model.predict(X_test_scaled)
fe_accuracy = accuracy_score(y_test, fe_pred)

print(f"Feature Engineering 전 정확도: {base_accuracy}")
print(f"Feature Engineering 후 정확도: {fe_accuracy}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-6448bd3e5d11> in <cell line: 8>()
#       6
#       7 file = '/content/drive/MyDrive/Colab Notebooks/winequality-red.csv'
# ----> 8 data = pd.read_csv(file)
#       9
#      10 data['quality'] = data['quality'].apply(lambda x: 1 if x >= 6 else 0)
#
# ...
